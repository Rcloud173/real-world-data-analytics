# %%
import numpy as np
import pandas as pd
import requests
import time

# %%
# importing the countries.
url = "https://api.worldbank.org/countries?format=json&per_page=300"

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
data = response.json()
print(data[0])
print(data[1])
print(len(data))
# Out:
# {'page': 1, 'pages': 1, 'per_page': '300', 'total': 296}
# [{'id': 'ABW', 'iso2Code': 'AW', 'name': 'Aruba', 'region': {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Latin America & Caribbean '}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Oranjestad', 'longitude': '-70.0167', 'latitude': '12.5167'}, {'id': 'AFE', 'iso2Code': 'ZH', 'name': 'Africa Eastern and Southern', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AFG', 'iso2Code': 'AF', 'name': 'Afghanistan', 'region': {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Middle East, North Africa, Afghanistan & Pakistan'}, 'adminregion': {'id': 'MNA', 'iso2code': 'XQ', 'value': 'Middle East, North Africa, Afghanistan & Pakistan (excluding high income)'}, 'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'}, 'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}, 'capitalCity': 'Kabul', 'longitude': '69.1761', 'latitude': '34.5228'}, {'id': 'AFR', 'iso2Code': 'A9', 'name': 'Africa', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AFW', 'iso2Code': 'ZI', 'name': 'Africa Western and Central', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AGO', 'iso2Code': 'AO', 'name': 'Angola', 'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}, 'adminregion': {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-Saharan Africa (excluding high income)'}, 'incomeLevel': {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lower middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Luanda', 'longitude': '13.242', 'latitude': '-8.81155'}, {'id': 'ALB', 'iso2Code': 'AL', 'name': 'Albania', 'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}, 'adminregion': {'id': 'ECA', 'iso2code': '7E', 'value': 'Europe & Central Asia (excluding high income)'}, 'incomeLevel': {'id': 'UMC', 'iso2code': 'XT', 'value': 'Upper middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Tirane', 'longitude': '19.8172', 'latitude': '41.3317'}, {'id': 'AND', 'iso2Code': 'AD', 'name': 'Andorra', 'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Andorra la Vella', 'longitude': '1.5218', 'latitude': '42.5075'}, {'id': 'ARB', 'iso2Code': '1A', 'name': 'Arab World', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'ARE', 'iso2Code': 'AE', 'name': 'United Arab Emirates', 'region': {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Middle East, North Africa, Afghanistan & Pakistan'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High inc ...
# 2

# %%
countries= data[1]
countries= pd.DataFrame(countries)

# %%
countries["incomeLevel"][6]
# Out:
# {'id': 'UMC', 'iso2code': 'XT', 'value': 'Upper middle income'}

# %%
countries.head()
# Out:
#     id iso2Code                         name  \
# 0  ABW       AW                        Aruba
# 1  AFE       ZH  Africa Eastern and Southern
# 2  AFG       AF                  Afghanistan
# 3  AFR       A9                       Africa
# 4  AFW       ZI   Africa Western and Central
#
#                                               region  \
# 0  {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 1  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 2  {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Midd...
# 3  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 4  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
#
#                                          adminregion  \
# 0            {'id': '', 'iso2code': '', 'value': ''}
# 1            {'id': '', 'iso2code': '', 'value': ''}
# 2  {'id': 'MNA', 'iso2code': 'XQ', 'value': 'Midd...
# 3            {'id': '', 'iso2code': '', 'value': ''}
# 4            {'id': '', 'iso2code': '', 'value': ''}
#
#                                          incomeLevel  \
# 0  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...
# 1  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 2  {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low ...
# 3  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 4  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
#
#                                          lendingType capitalCity longitude  \
# 0  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...  Oranjestad  -70.0167
# 1  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 2    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}       Kabul   69.1761
# 3  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 4  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
#
#   latitude
# 0  12.5167
# 1
# 2  34.5228
# 3
# 4

# %%
countries["region"]=countries["region"].apply(lambda x:x["value"])

# %%
countries["incomeLevel"]=countries["incomeLevel"].apply(lambda x:x["value"])

# %%
countries["lendingType"]=countries["lendingType"].apply(lambda x:x["value"])

# %%
countries.drop(columns=["adminregion","capitalCity"], inplace=True)

# %%
countries["region"].unique()
# Out:
# array(['Latin America & Caribbean ', 'Aggregates',
#        'Middle East, North Africa, Afghanistan & Pakistan',
#        'Sub-Saharan Africa ', 'Europe & Central Asia',
#        'East Asia & Pacific', 'South Asia', 'North America'], dtype=object)

# %%
countries.rename(columns={"iso2Code":"country_id"}, inplace=True)

# %%
countries[countries["region"]=="Affregates"]
# Out:
# Empty DataFrame
# Columns: [id, country_id, name, region, incomeLevel, lendingType, longitude, latitude]
# Index: []

# %%
base_url="https://api.worldbank.org/v2/indicators?format=json"
response = requests.get(base_url)
response.status_code
# Out:
# 200

# %%
indicators_data = response.json()

# %%
indicators_data[0]
# Out:
# {'page': 1, 'pages': 587, 'per_page': '50', 'total': 29323}

# %%
indicators_data[1]
# Out:
# [{'id': '1.0.HCount.1.90usd',
#   'name': 'Poverty Headcount ($1.90 a day)',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2011 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.HCount.2.5usd',
#   'name': 'Poverty Headcount ($2.50 a day)',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.HCount.Mid10to50',
#   'name': 'Middle Class ($10-50 a day) Headcount',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.HCount.Ofcl',
#   'name': 'Official Moderate Poverty Rate-National',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income below the official poverty line developed by each country.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of data from National Statistical Offices.',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.HCount.Poor4uds',
#   'name': 'Poverty Headcount ($4 a day)',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.HCount.Vul4to10',
#   'name': 'Vulnerable ($4-10 a day) Headcount',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.PGap.1.90usd',
#   'name': 'Poverty Gap ($1.90 a day)',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.PGap.2.5usd',
#   'name': 'Poverty Gap ($2.50 a day)',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.PGap.Poor4uds',
#   'name': 'Poverty Gap ($4 a day)',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.PSev.1.90usd',
#   'name': 'Poverty Severity ($1.90 a day)',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.PSev.2.5usd',
#   'name': 'Poverty Severity ($2.50 a day)',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.0.PSev.Poor4uds',
#   'name': 'Poverty Severity ($4 a day)',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.HCount.1.90usd',
#   'name': 'Poverty Headcount ($1.90 a day)-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2011 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.HCount.2.5usd',
#   'name': 'Poverty Headcount ($2.50 a day)-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.HCount.Mid10to50',
#   'name': 'Middle Class ($10-50 a day) Headcount-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.HCount.Ofcl',
#   'name': 'Official Moderate Poverty Rate- Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income below the official poverty line developed by each country.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of data from National Statistical Offices.',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.HCount.Poor4uds',
#   'name': 'Poverty Headcount ($4 a day)-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.HCount.Vul4to10',
#   'name': 'Vulnerable ($4-10 a day) Headcount-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.PGap.1.90usd',
#   'name': 'Poverty Gap ($1.90 a day)-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.PGap.2.5usd',
#   'name': 'Poverty Gap ($2.50 a day)-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.PGap.Poor4uds',
#   'name': 'Poverty Gap ($4 a day)-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.PSev.1.90usd',
#   'name': 'Poverty Severity ($1.90 a day)-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.PSev.2.5usd',
#   'name': 'Poverty Severity ($2.50 a day)-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1.PSev.Poor4uds',
#   'name': 'Poverty Severity ($4 a day)-Rural',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.1_ACCESS.ELECTRICITY.TOT',
#   'name': 'Access to electricity (% of total population)',
#   'unit': '',
#   'source': {'id': '35', 'value': 'Sustainable Energy for All'},
#   'sourceNote': 'Access to electricity is the percentage of population with access to electricity.',
#   'sourceOrganization': 'World Bank Global Electrification Database 2012',
#   'topics': []},
#  {'id': '1.1_TOTAL.FINAL.ENERGY.CONSUM',
#   'name': 'Total final energy consumption (TFEC)',
#   'unit': '',
#   'source': {'id': '35', 'value': 'Sustainable Energy for All'},
#   'sourceNote': 'Total final energy consumption (TFEC): This indicator is derived form energy balances statistics and is equivalent to total final consumption excluding non-energy use.',
#   'sourceOrganization': 'World Bank and International Energy Agency (IEA Statistics © OECD/IEA, http://www.iea.org/stats/index.asp).  ',
#   'topics': []},
#  {'id': '1.1_YOUTH.LITERACY.RATE',
#   'name': 'Literacy rate, youth total (% of people ages 15-24) ',
#   'unit': '',
#   'source': {'id': '34', 'value': 'Global Partnership for Education'},
#   'sourceNote': 'The number of persons aged 15 to 24 years who can both read and write with understanding a short simple statement on their everyday life, divided by the population in that age group. Generally, ‘literacy’ also encompasses ‘numeracy’, the ability to make simple arithmetic calculations. For further country-specific definition details please refer to the source of information, the UNESCO Institute for Statistics (UIS): www.uis.unesco.org',
#   'sourceOrganization': 'Source of information: UNESCO Institute for Statistics (www.uis.unesco.org). Please refer to its website for country-specific details on the specific national data sources and method used. ',
#   'topics': []},
#  {'id': '1.2.HCount.1.90usd',
#   'name': 'Poverty Headcount ($1.90 a day)-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2011 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.HCount.2.5usd',
#   'name': 'Poverty Headcount ($2.50 a day)-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.HCount.Mid10to50',
#   'name': 'Middle Class ($10-50 a day) Headcount-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.HCount.Ofcl',
#   'name': 'Official Moderate Poverty Rate-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income below the official poverty line developed by each country.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of data from National Statistical Offices.',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.HCount.Poor4uds',
#   'name': 'Poverty Headcount ($4 a day)-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.HCount.Vul4to10',
#   'name': 'Vulnerable ($4-10 a day) Headcount-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.PGap.1.90usd',
#   'name': 'Poverty Gap ($1.90 a day)-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.PGap.2.5usd',
#   'name': 'Poverty Gap ($2.50 a day)-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.PGap.Poor4uds',
#   'name': 'Poverty Gap ($4 a day)-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.PSev.1.90usd',
#   'name': 'Poverty Severity ($1.90 a day)-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.PSev.2.5usd',
#   'name': 'Poverty Severity ($2.50 a day)-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2.PSev.Poor4uds',
#   'name': 'Poverty Severity ($4 a day)-Urban',
#   'unit': '',
#   'source': {'id': '37', 'value': 'LAC Equity Lab'},
#   'sourceNote': 'The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line',
#   'sourceOrganization': 'LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).',
#   'topics': [{'id': '11', 'value': 'Poverty '}]},
#  {'id': '1.2_ACCESS.ELECTRICITY.RURAL',
#   'name': 'Access to electricity (% of rural population)',
#   'unit': '',
#   'source': {'id': '35', 'value': 'Sustainable Energy for All'},
#   'sourceNote': 'Access to electricity is the percentage of rural population with access to electricity. ',
#   'sourceOrganization': 'World Bank Global Electrification Database 2013',
#   'topics': []},
#  {'id': '1.3_ACCESS.ELECTRICITY.URBAN',
#   'name': 'Access to electricity (% of urban population)',
#   'unit': '',
#   'source': {'id': '35', 'value': 'Sustainable Energy for All'},
#   'sourceNote': 'Access to electricity is the percentage of total population with access to electricity. ',
#   'sourceOrganization': 'World Bank Global Electrification Database 2014',
#   'topics': []},
#  {'id': '100000',
#   'name': '100000:GROSS DOMESTIC PRODUCT',
#   'unit': '',
#   'source': {'id': '71',
#    'value': 'International Comparison Program (ICP) 2005'},
#   'sourceNote': '',
#   'sourceOrganization': '',
#   'topics': []},
#  {'id': '1000000',
#   'name': '1000000:GROSS DOMESTIC PRODUCT',
#   'unit': '',
#   'source': {'id': '78', 'value': 'ICP 2017'},
#   'sourceNote': '',
#   'sourceOrganization': '',
#   'topics': []},
#  {'id': '110000',
#   'name': '110000:INDIVIDUAL CONSUMPTION EXPENDITURE BY HOUSEHOLDS',
#   'unit': '',
#   'source': {'id': '71',
#    'value': 'International Comparison Program (ICP) 2005'},
#   'sourceNote': '',
#   'sourceOrganization': '',
#   'topics': []},
#  {'id': '110100',
#   'name': '110100:FOOD AND NON-ALCOHOLIC BEVERAGES',
#   'unit': '',
#   'source': {'id': '71',
#    'value': 'International Comparison Program (ICP) 2005'},
#   'sourceNote': '',
#   'sourceOrganization': '',
#   'topics': []},
#  {'id': '1101000',
#   'name': '1101000:FOOD AND NON-ALCOHOLIC BEVERAGES',
#   'unit': '',
#   'source': {'id': '78', 'value': 'ICP 2017'},
#   'sourceNote': '',
#   'sourceOrganization': '',
#   'topics': []},
#  {'id': '110110',
#   'name': '110110:FOOD',
#   'unit': '',
#   'source': {'id': '71',
#    'value': 'International Comparison Program (ICP) 2005'},
#   'sourceNote': '',
#   'sourceOrganization': '',
#   'topics': []},
#  {'id': '1101100',
#   'name': '1101100:FOOD',
#   'unit': '',
#   'source': {'id': '78', 'value': 'ICP 2017'},
#   'sourceNote': '',
#   'sourceOrganization': '',
#   'topics': []},
#  {'id': '110111',
#   'name': '110111:Bread and cereals (Class)',
#   'unit': '',
#   'source': {'id': '71',
#    'value': 'International Comparison Program (ICP) 2005'},
#   'sourceNote': '',
#   'sourceOrganization': '',
#   'topics': []},
#  {'id': '1101110',
#   'name': '1101110:Bread and cereals',
#   'unit': '',
#   'source': {'id': '78', 'value': 'ICP 2017'},
#   'sourceNote': '',
#   'sourceOrganization': '',
#   'topics': [{}]}]

# %%
all_dfs=[]
for  i in range(1,526):
  url= f"https://api.worldbank.org/v2/indicators?format=json&per_page=500&page={i}"
  response= requests.get(url)

  if response.status_code==200:
    data=response.json()

    if len(data)<2:
      print(f"No data at page{i}")

    indicators=data[1]
    df= pd.DataFrame([{"id":item["id"],
                   "name":item["name"]} for item in indicators ])
    all_dfs.append(df)
    print(f"Page{i}: {len(df)} indicators collected")
  else:
    print(f"Failed to fetch  page {i},status code {response.status_code}")
# Out:
# Page1: 500 indicators collected
# Page2: 500 indicators collected
# Page3: 500 indicators collected
# Page4: 500 indicators collected
# Page5: 500 indicators collected
# Page6: 500 indicators collected
# Page7: 500 indicators collected
# Page8: 500 indicators collected
# Page9: 500 indicators collected
# Page10: 500 indicators collected
# Page11: 500 indicators collected
# Page12: 500 indicators collected
# Page13: 500 indicators collected
# Page14: 500 indicators collected
# Page15: 500 indicators collected
# Page16: 500 indicators collected
# Page17: 500 indicators collected
# Page18: 500 indicators collected
# Page19: 500 indicators collected
# Page20: 500 indicators collected
# Page21: 500 indicators collected
# Page22: 500 indicators collected
# Page23: 500 indicators collected
# Page24: 500 indicators collected
# Page25: 500 indicators collected
# Page26: 500 indicators collected
# Page27: 500 indicators collected
# Page28: 500 indicators collected
# Page29: 500 indicators collected
# Page30: 500 indicators collected
# Page31: 500 indicators collected
# Page32: 500 indicators collected
# Page33: 500 indicators collected
# Page34: 500 indicators collected
# Page35: 500 indicators collected
# Page36: 500 indicators collected
# Page37: 500 indicators collected
# Page38: 500 indicators collected
# Page39: 500 indicators collected
# Page40: 500 indicators collected
# Page41: 500 indicators collected
# Page42: 500 indicators collected
# Page43: 500 indicators collected
# Page44: 500 indicators collected
# Page45: 500 indicators collected
# Page46: 500 indicators collected
# Page47: 500 indicators collected
# Page48: 500 indicators collected
# Page49: 500 indicators collected
# Page50: 500 indicators collected
# Page51: 500 indicators collected
# Page52: 500 indicators collected
# Page53: 500 indicators collected
# Page54: 500 indicators collected
# Page55: 500 indicators collected
# Page56: 500 indicators collected
# Page57: 500 indicators collected
# Page58: 500 indicators collected
# Page59: 323 indicators collected
# Page60: 0 indicators collected
# Page61: 0 indicators collected
# Page62: 0 indicators collected
# Page63: 0 indicators collected
# Page64: 0 indicators collected
# Page65: 0 indicators collected
# Page66: 0 indicators collected
# Page67: 0 indicators collected
# Page68: 0 indicators collected
# Page69: 0 indicators collected
# Page70: 0 indicators collected
# Page71: 0 indicators collected
# Page72: 0 indicators collected
# Page73: 0 indicators collected
# Page74: 0 indicators collected
# Page75: 0 indicators collected
# Page76: 0 indicators collected
# Page77: 0 indicators collected
# Page78: 0 indicators collected
# Page79: 0 indicators collected
# Page80: 0 indicators collected
# Page81: 0 indicators collected
# Page82: 0 indicators collected
# Page83: 0 indicators collected
# Page84: 0 indicators collected
# Page85: 0 indicators collected
# Page86: 0 indicators collected
# Page87: 0 indicators collected
# Page88: 0 indicators collected
# Page89: 0 indicators collected
# Page90: 0 indicators collected
# Page91: 0 indicators collected
# Page92: 0 indicators collected
# Page93: 0 indicators collected
# Page94: 0 indicators collected
# Page95: 0 indicators collected
# Page96: 0 indicators collected
# Page97: 0 indicators collected
# Page98: 0 indicators collected
# Page99: 0 indicators collected
# Page100: 0 indicators collected
# Page101: 0 indicators collected
# Page102: 0 indicators collected
# Page103: 0 indicators collected
# Page104: 0 indicators collected
# Page105: 0 indicators collected
# Page106: 0 indicators collected
# Page107: 0 indicators collected
# Page108: 0 indicators collected
# Page109: 0 indicators collected
# Page110: 0 indicators collected
# Page111: 0 indicators collected
# Page112: 0 indicators collected
# Page113: 0 indicators collected
# Page114: 0 indicators collected
# Page115: 0 indicators collected
# Page116: 0 indicators collected
# Page117: 0 indicators collected
# Page118: 0 indicators collected
# Page119: 0 indicators collected
# Page120: 0 indicators collected
# Page121: 0 indicators collected
# Page122: 0 indicators collected
# Page123: 0 indicators collected
# Page124: 0 indicators collected
# Page125: 0 indicators collected
# Page126: 0 indicators collected
# Page127: 0 indicators collected
# Page128: 0 indicators collected
# Page129: 0 indicators collected
# Page130: 0 indicators collected
# Page131: 0 indicators collected
# Page132: 0 indicators collected
# Page133: 0 indicators collected
# Page134: 0 indicators collected
# Page135: 0 indicators collected
# Page136: 0 indicators collected
# Page137: 0 indicators collected
# Page138: 0 indicators collected
# Page139: 0 indicators collected
# Page140: 0 indicators collected
# Page141: 0 indicators collected
# Page142: 0 indicators collected
# Page143: 0 indicators collected
# Page144: 0 indicators collected
# Page145: 0 indicators collected
# Page146: 0 indicators collected
# Page147: 0 indicators collected
# Page148: 0 indicators collected
# Page149: 0 indicators collected
# Page150: 0 indicators collected
# Page151: 0 indicators collected
# Page152: 0 indicators collected
# Page153: 0 indicators collected
# Page154: 0 indicators collected
# Page155: 0 indicators collected
# Page156: 0 indicators collected
# Page157: 0 indicators collected
# Page158: 0 indicators collected
# Page159: 0 indicators collected
# Page160: 0 indicators collected
# Page161: 0 indicators collected
# Page162: 0 indicators collected
# Page163: 0 indicators collected
# Page164: 0 indicators collected
# Page165: 0 indicators collected
# Page166: 0 indicators collected
# Page167: 0 indicators collected
# Page168: 0 indicators collected
# Page169: 0 indicators collected
# Page170: 0 indicators collected
# Page171: 0 indicators collected
# Page172: 0 indicators collected
# Page173: 0 indicators collected
# Page174: 0 indicators collected
# Page175: 0 indicators collected
# Page176: 0 indicators collected
# Page177: 0 indicators collected
# Page178: 0 indicators collected
# Page179: 0 indicators collected
# Page180: 0 indicators collected
# Page181: 0 indicators collected
# Page182: 0 indicators collected
# Page183: 0 indicators collected
# Page184: 0 indicators collected
# Page185: 0 indicators collected
# Page186: 0 indicators collected
# Page187: 0 indicators collected
# Page188: 0 indicators collected
# Page189: 0 indicators collected
# Page190: 0 indicators collected
# Page191: 0 indicators collected
# Page192: 0 indicators collected
# Page193: 0 indicators collected
# Page194: 0 indicators collected
# Page195: 0 indicators collected
# Page196: 0 indicators collected
# Page197: 0 indicators collected
# Page198: 0 indicators collected
# Page199: 0 indicators collected
# Page200: 0 indicators collected
# Page201: 0 indicators collected
# Page202: 0 indicators collected
# Page203: 0 indicators collected
# Page204: 0 indicators collected
# Page205: 0 indicators collected
# Page206: 0 indicators collected
# Page207: 0 indicators collected
# Page208: 0 indicators collected
# Page209: 0 indicators collected
# Page210: 0 indicators collected
# Page211: 0 indicators collected
# Page212: 0 indicators collected
# Page213: 0 indicators collected
# Page214: 0 indicators collected
# Page215: 0 indicators collected
# Page216: 0 indicators collected
# Page217: 0 indicators collected
# Page218: 0 indicators collected
# Page219: 0 indicators collected
# Page220: 0 indicators collected
# Page221: 0 indicators collected
# Page222: 0 indicators collected
# Page223: 0 indicators collected
# Page224: 0 indicators collected
# Page225: 0 indicators collected
# Page226: 0 indicators collected
# Page227: 0 indicators collected
# Page228: 0 indicators collected
# Page229: 0 indicators collected
# Page230: 0 indicators collected
# Page231: 0 indicators collected
# Page232: 0 indicators collected
# Page233: 0 indicators collected
# Page234: 0 indicators collected
# Page235: 0 indicators collected
# Page236: 0 indicators collected
# Page237: 0 indicators collected
# Page238: 0 indicators collected
# Page239: 0 indicators collected
# Page240: 0 indicators collected
# Page241: 0 indicators collected
# Page242: 0 indicators collected
# Page243: 0 indicators collected
# Page244: 0 indicators collected
# Page245: 0 indicators collected
# Page246: 0 indicators collected
# Page247: 0 indicators collected
# Page248: 0 indicators collected
# Page249: 0 indicators collected
# Page250: 0 indicators collected
# Page251: 0 indicators collected
# Page252: 0 indicators collected
# Page253: 0 indicators collected
# Page254: 0 indicators collected
# Page255: 0 indicators collected
# Page256: 0 indicators collected
# Page257: 0 indicators collected
# Page258: 0 indicators collected
# Page259: 0 indicators collected
# Page260: 0 indicators collected
# Page261: 0 indicators collected
# Page262: 0 indicators collected
# Page263: 0 indicators collected
# Page264: 0 indicators collected
# Page265: 0 indicators collected
# Page266: 0 indicators collected
# Page267: 0 indicators collected
# Page268: 0 indicators collected
# Page269: 0 indicators collected
# Page270: 0 indicators collected
# Page271: 0 indicators collected
# Page272: 0 indicators collected
# Page273: 0 indicators collected
# Page274: 0 indicators collected
# Page275: 0 indicators collected
# Page276: 0 indicators collected
# Page277: 0 indicators collected
# Page278: 0 indicators collected
# Page279: 0 indicators collected
# Page280: 0 indicators collected
# Page281: 0 indicators collected
# Page282: 0 indicators collected
# Page283: 0 indicators collected
# Page284: 0 indicators collected
# Page285: 0 indicators collected
# Page286: 0 indicators collected
# Page287: 0 indicators collected
# Page288: 0 indicators collected
# Page289: 0 indicators collected
# Page290: 0 indicators collected
# Page291: 0 indicators collected
# Page292: 0 indicators collected
# Page293: 0 indicators collected
# Page294: 0 indicators collected
# Page295: 0 indicators collected
# Page296: 0 indicators collected
# Page297: 0 indicators collected
# Page298: 0 indicators collected
# Page299: 0 indicators collected
# Page300: 0 indicators collected
# Page301: 0 indicators collected
# Page302: 0 indicators collected
# Page303: 0 indicators collected
# Page304: 0 indicators collected
# Page305: 0 indicators collected
# Page306: 0 indicators collected
# Page307: 0 indicators collected
# Page308: 0 indicators collected
# Page309: 0 indicators collected
# Page310: 0 indicators collected
# Page311: 0 indicators collected
# Page312: 0 indicators collected
# Page313: 0 indicators collected
# Page314: 0 indicators collected
# Page315: 0 indicators collected
# Page316: 0 indicators collected
# Page317: 0 indicators collected
# Page318: 0 indicators collected
# Page319: 0 indicators collected
# Page320: 0 indicators collected
# Page321: 0 indicators collected
# Page322: 0 indicators collected
# Page323: 0 indicators collected
# Page324: 0 indicators collected
# Page325: 0 indicators collected
# Page326: 0 indicators collected
# Page327: 0 indicators collected
# Page328: 0 indicators collected
# Page329: 0 indicators collected
# Page330: 0 indicators collected
# Page331: 0 indicators collected
# Page332: 0 indicators collected
# Page333: 0 indicators collected
# Page334: 0 indicators collected
# Page335: 0 indicators collected
# Page336: 0 indicators collected
# Page337: 0 indicators collected
# Page338: 0 indicators collected
# Page339: 0 indicators collected
# Page340: 0 indicators collected
# Page341: 0 indicators collected
# Page342: 0 indicators collected
# Page343: 0 indicators collected
# Page344: 0 indicators collected
# Page345: 0 indicators collected
# Page346: 0 indicators collected
# Page347: 0 indicators collected
# Page348: 0 indicators collected
# Page349: 0 indicators collected
# Page350: 0 indicators collected
# Page351: 0 indicators collected
# Page352: 0 indicators collected
# Page353: 0 indicators collected
# Page354: 0 indicators collected
# Page355: 0 indicators collected
# Page356: 0 indicators collected
# Page357: 0 indicators collected
# Page358: 0 indicators collected
# Page359: 0 indicators collected
# Page360: 0 indicators collected
# Page361: 0 indicators collected
# Page362: 0 indicators collected
# Page363: 0 indicators collected
# Page364: 0 indicators collected
# Page365: 0 indicators collected
# Page366: 0 indicators collected
# Page367: 0 indicators collected
# Page368: 0 indicators collected
# Page369: 0 indicators collected
# Page370: 0 indicators collected
# Page371: 0 indicators collected
# Page372: 0 indicators collected
# Page373: 0 indicators collected
# Page374: 0 indicators collected
# Page375: 0 indicators collected
# Page376: 0 indicators collected
# Page377: 0 indicators collected
# Page378: 0 indicators collected
# Page379: 0 indicators collected
# Page380: 0 indicators collected
# Page381: 0 indicators collected
# Page382: 0 indicators collected
# Page383: 0 indicators collected
# Page384: 0 indicators collected
# Page385: 0 indicators collected
# Page386: 0 indicators collected
# Page387: 0 indicators collected
# Page388: 0 indicators collected
# Page389: 0 indicators collected
# Page390: 0 indicators collected
# Page391: 0 indicators collected
# Page392: 0 indicators collected
# Page393: 0 indicators collected
# Page394: 0 indicators collected
# Page395: 0 indicators collected
# Page396: 0 indicators collected
# Page397: 0 indicators collected
# Page398: 0 indicators collected
# Page399: 0 indicators collected
# Page400: 0 indicators collected
# Page401: 0 indicators collected
# Page402: 0 indicators collected
# Page403: 0 indicators collected
# Page404: 0 indicators collected
# Page405: 0 indicators collected
# Page406: 0 indicators collected
# Page407: 0 indicators collected
# Page408: 0 indicators collected
# Page409: 0 indicators collected
# Page410: 0 indicators collected
# Page411: 0 indicators collected
# Page412: 0 indicators collected
# Page413: 0 indicators collected
# Page414: 0 indicators collected
# Page415: 0 indicators collected
# Page416: 0 indicators collected
# Page417: 0 indicators collected
# Page418: 0 indicators collected
# Page419: 0 indicators collected
# Page420: 0 indicators collected
# Page421: 0 indicators collected
# Page422: 0 indicators collected
# Page423: 0 indicators collected
# Page424: 0 indicators collected
# Page425: 0 indicators collected
# Page426: 0 indicators collected
# Page427: 0 indicators collected
# Page428: 0 indicators collected
# Page429: 0 indicators collected
# Page430: 0 indicators collected
# Page431: 0 indicators collected
# Page432: 0 indicators collected
# Page433: 0 indicators collected
# Page434: 0 indicators collected
# Page435: 0 indicators collected
# Page436: 0 indicators collected
# Page437: 0 indicators collected
# Page438: 0 indicators collected
# Page439: 0 indicators collected
# Page440: 0 indicators collected
# Page441: 0 indicators collected
# Page442: 0 indicators collected
# Page443: 0 indicators collected
# Page444: 0 indicators collected
# Page445: 0 indicators collected
# Page446: 0 indicators collected
# Page447: 0 indicators collected
# Page448: 0 indicators collected
# Page449: 0 indicators collected
# Page450: 0 indicators collected
# Page451: 0 indicators collected
# Page452: 0 indicators collected
# Page453: 0 indicators collected
# Page454: 0 indicators collected
# Page455: 0 indicators collected
# Page456: 0 indicators collected
# Page457: 0 indicators collected
# Page458: 0 indicators collected
# Page459: 0 indicators collected
# Page460: 0 indicators collected
# Page461: 0 indicators collected
# Page462: 0 indicators collected
# Page463: 0 indicators collected
# Page464: 0 indicators collected
# Page465: 0 indicators collected
# Page466: 0 indicators collected
# Page467: 0 indicators collected
# Page468: 0 indicators collected
# Page469: 0 indicators collected
# Page470: 0 indicators collected
# Page471: 0 indicators collected
# Page472: 0 indicators collected
# Page473: 0 indicators collected
# Page474: 0 indicators collected
# Page475: 0 indicators collected
# Page476: 0 indicators collected
# Page477: 0 indicators collected
# Page478: 0 indicators collected
# Page479: 0 indicators collected
# Page480: 0 indicators collected
# Page481: 0 indicators collected
# Page482: 0 indicators collected
# Page483: 0 indicators collected
# Page484: 0 indicators collected
# Page485: 0 indicators collected
# Page486: 0 indicators collected
# Page487: 0 indicators collected
# Page488: 0 indicators collected
# Page489: 0 indicators collected
# Page490: 0 indicators collected
# Page491: 0 indicators collected
# Page492: 0 indicators collected
# Page493: 0 indicators collected
# Page494: 0 indicators collected
# Page495: 0 indicators collected
# Page496: 0 indicators collected
# Page497: 0 indicators collected
# Page498: 0 indicators collected
# Page499: 0 indicators collected
# Page500: 0 indicators collected
# Page501: 0 indicators collected
# Page502: 0 indicators collected
# Page503: 0 indicators collected
# Page504: 0 indicators collected
# Page505: 0 indicators collected
# Page506: 0 indicators collected
# Page507: 0 indicators collected
# Page508: 0 indicators collected
# Page509: 0 indicators collected
# Page510: 0 indicators collected
# Page511: 0 indicators collected
# Page512: 0 indicators collected
# Page513: 0 indicators collected
# Page514: 0 indicators collected
# Page515: 0 indicators collected
# Page516: 0 indicators collected
# Page517: 0 indicators collected
# Page518: 0 indicators collected
# Page519: 0 indicators collected
# Page520: 0 indicators collected
# Page521: 0 indicators collected
# Page522: 0 indicators collected
# Page523: 0 indicators collected
# Page524: 0 indicators collected
# Page525: 0 indicators collected

# %%
final_df = pd.concat(all_dfs, ignore_index=True)

# %%
final_df.to_csv("final_df.csv")

# %%
indicator_groups = {
"economic_activity_growth": [
"NY.GDP.MKTP.KD.ZG", # GDP growth (annual %)
"NY.GDP.PCAP.CD" # GDP per capita (current US$)
],
"labour_market_indicators": [
"SL.UEM.TOTL.ZS", # Unemployment total
"SL.UEM.1524.ZS", # Unemployment youth total (ages 15–24)
"SL.TLF.TOTL.IN" # Labour force, total
],
"trade_globalization": [
"NE.EXP.GNFS.CD", # Exports of goods and services (current US$)
"NE.IMP.GNFS.CD" # Imports of goods and services (current US$)
],
"poverty_inequality": [
"SI.POV.NAHC", # Poverty headcount ratio at national poverty lines (% of population)
"SI.POV.GINI" # Gini index (measure of income inequality)
],
"environmental_indicators": [
"EG.FEC.RNEW.ZS", # Renewable energy consumption (% of total final energy consumption)
"AG.LND.FRST.ZS" # Forest area (% of land area)
],
"health_indicators": [
"SP.DYN.LE00.IN", # Life expectancy at birth
"SP.DYN.IMRT.IN", # Infant mortality rate
"SH.H2O.BASW.ZS", # Access to at least basic water services (% of population)
"SH.XPD.CHEX.GD.ZS", # Current health expenditure (% of GDP)
"SH.IMM.IDPT", # Immunization, DPT (% of children ages 12–23 months)
"SH.IMM.MEAS", # Immunization, measles (% of children ages 12–23 months)
"SH.MMR.RISK.ZS", # Risk of maternal death
"SH.DTH.COMM.ZS", # Deaths from communicable diseases (% of total)
"SH.TBS.INCD", # Tuberculosis incidence (per 100,000 people)
"SH.STA.BRTC.ZS", # Births attended by skilled health staff (%)
"SH.STA.MMRT", # Maternal mortality ratio (modeled estimate, per 100,000 live births)
"SP.POP.65UP.TO.ZS", # Population ages 65 and above (% of total population)
"SH.HIV.INCD.ZS" # HIV incidence rate (per 1,000 uninfected population ages 15–49)
],
"technology_indicators": [
"IT.NET.USER.ZS", # Individuals using the Internet (% of population)
"IT.CEL.SETS.P2" # Mobile cellular subscriptions (per 100 people)
]}

# %%
for i,j in indicator_groups.items():
    print(j)
# Out:
# ['NY.GDP.MKTP.KD.ZG', 'NY.GDP.PCAP.CD']
# ['SL.UEM.TOTL.ZS', 'SL.UEM.1524.ZS', 'SL.TLF.TOTL.IN']
# ['NE.EXP.GNFS.CD', 'NE.IMP.GNFS.CD']
# ['SI.POV.NAHC', 'SI.POV.GINI']
# ['EG.FEC.RNEW.ZS', 'AG.LND.FRST.ZS']
# ['SP.DYN.LE00.IN', 'SP.DYN.IMRT.IN', 'SH.H2O.BASW.ZS', 'SH.XPD.CHEX.GD.ZS', 'SH.IMM.IDPT', 'SH.IMM.MEAS', 'SH.MMR.RISK.ZS', 'SH.DTH.COMM.ZS', 'SH.TBS.INCD', 'SH.STA.BRTC.ZS', 'SH.STA.MMRT', 'SP.POP.65UP.TO.ZS', 'SH.HIV.INCD.ZS']
# ['IT.NET.USER.ZS', 'IT.CEL.SETS.P2']

# %%
import time
base_url="https://api.worldbank.org/countries/all/indicators/{}?format=json&per_page=1000&page={}"


category_dataframes={}
for category,indicators  in indicator_groups.items():
  print(f"Fetch intofmation  for category:{category}")
  all_dfs_for_category=[]


  for indicator_code in indicators:
    print(f"Fetching indicator: {indicator_code}")
    page=1

    while True:
      url = base_url.format(indicator_code, page)
      reponse= requests.get(url)
      if response.status_code!=200:
        print(f"No data for indicator{indicator_code} on page {page}")

      data = reponse.json()
      if len(data)<2:
        print(f"failed at page{page}")
        break

      total_pages = data[0]["pages"]
      record= data[1]

      df= pd.json_normalize(record)
      df= df[[
          "country.id","country.value","indicator.id",
          "indicator.value","date","value"
          ]].rename(columns={
              "country.id":"country_id",
              "country.value":"country_value",
              "indicator.id":"indicator_id",
              "indicator.value":"indicator_name",
              "date":"year"
          })

      df= df[df["year"].astype(int)>2015]
      all_dfs_for_category.append(df)

      if page>=total_pages:
        break
      else:
        page+=1
        time.sleep(0.3)

  if all_dfs_for_category:
      combined_df= pd.concat(all_dfs_for_category, ignore_index=True)
      category_dataframes[category]=combined_df
      print(f"Total rows  collected for {category}:{len(combined_df)}")
  else:
      print(f"No data collected for {category}")


print("Data Fetching completed")
# Out:
# Fetch intofmation  for category:economic_activity_growth
# Fetching indicator: NY.GDP.MKTP.KD.ZG
# Fetching indicator: NY.GDP.PCAP.CD
# Total rows  collected for economic_activity_growth:4788
# Fetch intofmation  for category:labour_market_indicators
# Fetching indicator: SL.UEM.TOTL.ZS
# Fetching indicator: SL.UEM.1524.ZS
# Fetching indicator: SL.TLF.TOTL.IN
# Total rows  collected for labour_market_indicators:7182
# Fetch intofmation  for category:trade_globalization
# Fetching indicator: NE.EXP.GNFS.CD
# Fetching indicator: NE.IMP.GNFS.CD
# Total rows  collected for trade_globalization:4788
# Fetch intofmation  for category:poverty_inequality
# Fetching indicator: SI.POV.NAHC
# Fetching indicator: SI.POV.GINI
# C:\Users\amirs\AppData\Local\Temp\ipykernel_22468\3703965186.py:51: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df= pd.concat(all_dfs_for_category, ignore_index=True)
# Total rows  collected for poverty_inequality:4788
# Fetch intofmation  for category:environmental_indicators
# Fetching indicator: EG.FEC.RNEW.ZS
# Fetching indicator: AG.LND.FRST.ZS
# Total rows  collected for environmental_indicators:4788
# Fetch intofmation  for category:health_indicators
# Fetching indicator: SP.DYN.LE00.IN
# Fetching indicator: SP.DYN.IMRT.IN
# Fetching indicator: SH.H2O.BASW.ZS
# Fetching indicator: SH.XPD.CHEX.GD.ZS
# Fetching indicator: SH.IMM.IDPT
# Fetching indicator: SH.IMM.MEAS
# Fetching indicator: SH.MMR.RISK.ZS
# Fetching indicator: SH.DTH.COMM.ZS
# Fetching indicator: SH.TBS.INCD
# Fetching indicator: SH.STA.BRTC.ZS
# Fetching indicator: SH.STA.MMRT
# Fetching indicator: SP.POP.65UP.TO.ZS
# Fetching indicator: SH.HIV.INCD.ZS
# Total rows  collected for health_indicators:31122
# Fetch intofmation  for category:technology_indicators
# Fetching indicator: IT.NET.USER.ZS
# Fetching indicator: IT.CEL.SETS.P2
# Total rows  collected for technology_indicators:4788
# Data Fetching completed

# %%
economic_activity= category_dataframes.get("economic_activity_growth", pd.DataFrame())
labour_market_jobs= category_dataframes.get("labour_market_indicators", pd.DataFrame())
trade_globalization= category_dataframes.get("trade_globalization", pd.DataFrame())
poverty_inequality= category_dataframes.get("poverty_inequality", pd.DataFrame())
environmental_indicators= category_dataframes.get("environmental_indicators", pd.DataFrame())
health_indicators= category_dataframes.get("health_indicators", pd.DataFrame())
technology_indicators= category_dataframes.get("technology_indicators", pd.DataFrame())

# %%
economic= pd.merge(economic_activity, countries, on ="country_id", how="inner")
labour_market = pd.merge(labour_market_jobs, countries, on ="country_id", how="inner")
trade= pd.merge(trade_globalization, countries, on ="country_id", how="inner")
poverty= pd.merge(poverty_inequality, countries, on ="country_id", how="inner")
environment= pd.merge(environmental_indicators, countries, on ="country_id", how="inner")
health=pd.merge(health_indicators, countries, on ="country_id", how="inner")
technology=pd.merge(technology_indicators, countries, on ="country_id", how="inner")

# %%
economic.drop(columns=["indicator_id","name","id"], inplace=True)
trade.drop(columns=["indicator_id","name","id"], inplace=True)
labour_market.drop(columns=["indicator_id","name","id"], inplace=True)
poverty.drop(columns=["indicator_id","name","id"], inplace=True)
environment.drop(columns=["indicator_id","name","id"], inplace=True)
health.drop(columns=["indicator_id","name","id"], inplace=True)
technology.drop(columns=["indicator_id","name","id"], inplace=True)

# %%
health
# Out:
#       country_id                country_value  \
# 0             ZH  Africa Eastern and Southern
# 1             ZH  Africa Eastern and Southern
# 2             ZH  Africa Eastern and Southern
# 3             ZH  Africa Eastern and Southern
# 4             ZH  Africa Eastern and Southern
# ...          ...                          ...
# 31117         ZW                     Zimbabwe
# 31118         ZW                     Zimbabwe
# 31119         ZW                     Zimbabwe
# 31120         ZW                     Zimbabwe
# 31121         ZW                     Zimbabwe
#
#                                           indicator_name  year      value  \
# 0                Life expectancy at birth, total (years)  2024        NaN
# 1                Life expectancy at birth, total (years)  2023  65.146291
# 2                Life expectancy at birth, total (years)  2022  64.487020
# 3                Life expectancy at birth, total (years)  2021  62.979999
# 4                Life expectancy at birth, total (years)  2020  63.766484
# ...                                                  ...   ...        ...
# 31117  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2020   1.900000
# 31118  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2019   2.300000
# 31119  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2018   2.700000
# 31120  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2017   3.600000
# 31121  Incidence of HIV, ages 15-49 (per 1,000 uninfe...  2016   4.700000
#
#                     region          incomeLevel lendingType longitude  \
# 0               Aggregates           Aggregates  Aggregates
# 1               Aggregates           Aggregates  Aggregates
# 2               Aggregates           Aggregates  Aggregates
# 3               Aggregates           Aggregates  Aggregates
# 4               Aggregates           Aggregates  Aggregates
# ...                    ...                  ...         ...       ...
# 31117  Sub-Saharan Africa   Lower middle income       Blend   31.0672
# 31118  Sub-Saharan Africa   Lower middle income       Blend   31.0672
# 31119  Sub-Saharan Africa   Lower middle income       Blend   31.0672
# 31120  Sub-Saharan Africa   Lower middle income       Blend   31.0672
# 31121  Sub-Saharan Africa   Lower middle income       Blend   31.0672
#
#        latitude
# 0
# 1
# 2
# 3
# 4
# ...         ...
# 31117  -17.8312
# 31118  -17.8312
# 31119  -17.8312
# 31120  -17.8312
# 31121  -17.8312
#
# [31122 rows x 10 columns]

# %%
economic.to_csv("ecnomic.csv")
labour_market.to_csv("labout_market.csv")
poverty.to_csv("poverty.csv")
environment.to_csv("environment.csv")
health.to_csv("healt.csv")
technology.to_csv("technology.csv")
